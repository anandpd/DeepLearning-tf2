# %%
import os

# %%
data_dir = "E:\\cell_images"

# %%
os.listdir(data_dir)
# Out:
# ['test', 'train']

# %%
import numpy as np, pandas as pd, seaborn as sns, matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12,8)

# %%
from matplotlib.image import imread

# %%
test_path = data_dir+'\\test'
train_path = data_dir+'\\train'

# %%
test_path
# Out:
# 'E:\\cell_images\\test'

# %%
os.listdir(test_path)
# Out:
# ['parasitized', 'uninfected']

# %% [markdown]
# ### Dataset Used : Malaria Dataset from National Library of Medicines,USA
#     URL :
#     https://lhncbc.nlm.nih.gov/publication/pub9932
#     Dataset Link :
#     ftp://lhcftp.nlm.nih.gov/Open-Access-Datasets/Malaria/cell_images.zip

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(train_path+'\\parasitized')[:10]
# Out:
# ['C100P61ThinF_IMG_20150918_144104_cell_162.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_163.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_164.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_165.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_166.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_167.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_168.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_169.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_170.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_171.png']

# %%
os.listdir(train_path+'\\parasitized')[0]
# Out:
# 'C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
para_cell = train_path+'\\parasitized\\'+'C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
para_cell
# Out:
# 'E:\\cell_images\\train\\parasitized\\C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
imread(para_cell).shape
# Out:
# (148, 142, 3)

# %%
plt.imshow(imread(para_cell))

# %%
os.listdir(train_path+'\\uninfected')[0]
# Out:
# 'C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
un_cell = train_path + '\\uninfected' +'\\C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
un_cell
# Out:
# 'E:\\cell_images\\train\\uninfected\\C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
un_cell = imread(un_cell)

# %%
plt.imshow(un_cell)

# %%
dim1, dim2 = [], []
for filename in os.listdir(test_path+'\\uninfected'):
    
    img = imread(test_path+'\\uninfected\\'+filename)
    d1, d2, colors = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
sns.jointplot(dim1, dim2)

# %%
np.mean(dim1)
# Out:
# 130.92538461538462

# %%
np.mean(dim2)
# Out:
# 130.75

# %%
imageShape = (130,130,3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
                    
image_gen = ImageDataGenerator(rotation_range=20,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               shear_range=0.1,
                               zoom_range=0.1,
                               horizontal_flip=True,
                               fill_mode='nearest' )

# %%
plt.imshow(un_cell)

# %%
plt.imshow(imread(para_cell))

# %%
plt.imshow(image_gen.random_transform(imread(para_cell)))

# %%
image_gen.flow_from_directory(train_path+'\\')
# Out:
# Found 24958 images belonging to 2 classes.

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
image_gen.flow_from_directory(test_path+'\\')
# Out:
# Found 2600 images belonging to 2 classes.

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPool2D, Dropout

# %%
model = Sequential([
    
Conv2D(filters=32, kernel_size=(3,3), input_shape=imageShape, activation='relu'),
MaxPool2D(pool_size=(2,2)),

Conv2D(filters=64, kernel_size=(3,3), input_shape=imageShape, activation='relu'),
MaxPool2D(pool_size=(2,2)),

Conv2D(filters=64, kernel_size=(3,3), input_shape=imageShape, activation='relu'),
MaxPool2D(pool_size=(2,2)),

Flatten(),
Dense(units=128, activation='relu'),
Dropout(0.5),
Dense(units=1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 62, 62, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 29, 29, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
earlyStop = EarlyStopping(monitor='val_loss', patience=2)

# %%
batchSize= 16

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                                target_size=imageShape[:2],
                                                color_mode='rgb',
                                                batch_size=batchSize,
                                                class_mode='binary')
# Out:
# Found 24958 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=imageShape[:2],
                                               color_mode='rgb',
                                               batch_size=batchSize,
                                               class_mode='binary',shuffle=False)
# Out:
# Found 2600 images belonging to 2 classes.

# %%
res = model.fit(train_image_gen, epochs=20, validation_data=test_image_gen, callbacks=[earlyStop])
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 1560 steps, validate for 163 steps
# Epoch 1/20
# 1560/1560 [==============================] - 1105s 708ms/step - loss: 0.9022 - accuracy: 0.5454 - val_loss: 0.6842 - val_accuracy: 0.5612
# Epoch 2/20
# 1560/1560 [==============================] - 774s 496ms/step - loss: 0.6800 - accuracy: 0.5782 - val_loss: 0.6794 - val_accuracy: 0.5892
# Epoch 3/20
# 1560/1560 [==============================] - 803s 515ms/step - loss: 0.6761 - accuracy: 0.5883 - val_loss: 0.6719 - val_accuracy: 0.5881
# Epoch 4/20
# 1560/1560 [==============================] - 798s 512ms/step - loss: 0.4384 - accuracy: 0.7833 - val_loss: 0.2050 - val_accuracy: 0.9323
# Epoch 5/20
# 1560/1560 [==============================] - 867s 556ms/step - loss: 0.1923 - accuracy: 0.9380 - val_loss: 0.1940 - val_accuracy: 0.9308
# Epoch 6/20
# ...

# %%
train_image_gen.class_indices
# Out:
# {'parasitized': 0, 'uninfected': 1}

# %%
test_image_gen.class_indices
# Out:
# {'parasitized': 0, 'uninfected': 1}

# %%
from tensorflow.keras.models import load_model

# %%
model.save('Malaria Detector.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 62, 62, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 29, 29, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.902183  0.545356  0.684159      0.561154
# 1  0.680009  0.578171  0.679358      0.589231
# 2  0.676093  0.588308  0.671945      0.588077
# 3  0.438383  0.783316  0.205016      0.932308
# 4  0.192296  0.937976  0.194014      0.930769
# 5  0.183744  0.940981  0.179081      0.943462
# 6  0.174850  0.946029  0.179513      0.937692
# 7  0.175290  0.944988  0.160205      0.945769
# 8  0.173537  0.946751  0.163751      0.943846
# 9  0.168828  0.946510  0.189716      0.937692

# %%
losses.columns
# Out:
# Index(['loss', 'accuracy', 'val_loss', 'val_accuracy'], dtype='object')

# %%
losses[['loss','val_loss']].plot()

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
model.evaluate(test_image_gen)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 163/163 [==============================] - 43s 262ms/step - loss: 0.1900 - accuracy: 0.9350
# [0.1900417079696963, 0.935]

# %%
pred = model.predict(test_image_gen)

# %%
threshold = 0.5
predictions = pred > threshold

# %%
predictions
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
len(pred)
# Out:
# 2600

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
test_image_gen.classes
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
print(classification_report(test_image_gen.classes, predictions))
# Out:
# precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      1300
#            1       0.94      0.94      0.94      1300
#
#     accuracy                           0.94      2600
#    macro avg       0.94      0.94      0.94      2600
# weighted avg       0.94      0.94      0.94      2600

# %%
print(confusion_matrix(test_image_gen.classes, predictions))
# Out:
# [[1218   82]
#  [  73 1227]]

# %%
sns.heatmap(confusion_matrix(test_image_gen.classes, predictions))

# %%
para_cell
# Out:
# 'E:\\cell_images\\train\\parasitized\\C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
from tensorflow.keras.preprocessing import image

# %%
testImage = image.load_img(para_cell, target_size=imageShape)

# %%
testImage
# Out:
# <PIL.Image.Image image mode=RGB size=130x130 at 0x2B8B6E75288>

# %%
testImageArray = image.img_to_array(testImage)

# %%
testImageArray.shape
# Out:
# (130, 130, 3)

# %%
testImageArray = testImageArray.reshape(1,130,130,3)

# %%
testImageArray.shape
# Out:
# (1, 130, 130, 3)

# %%
model.predict(testImageArray)
# Out:
# array([[8.7386594e-05]], dtype=float32)

# %%
# 0 corrosponds to uninfected and 1 corrosponds to Parasitized
